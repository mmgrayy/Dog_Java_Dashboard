# %% [markdown]
# # Data Retrieval
# - In this notebook, we will be retrieving, cleaning, and combining data from 3 separate resources
# - https://www.kaggle.com/search?q=dog+breed+characteristics+in%3Adatasets
# - https://marketplace.akc.org/puppies
# - https://thedogapi.com/

# %%
#import needed dependencies 
from bs4 import BeautifulSoup
import requests
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import time
import os 
import csv 
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import json
import requests
from pprint import pprint
import scipy.stats as st
import pymongo

# %%
#import api key from config to keep hidden 
from config import api_key

# %% [markdown]
# # The Dog API Pull
# - To begin, we will plug in our api_key to The Dog API url and use .read_json to create a dataframe that contains various breed information
# - The Dog API Documentation: https://documenter.getpostman.com/view/5578104/RWgqUxxi#f56d4ae2-8a89-4c3a-a22f-04db0459023f

# %%
#plug in url and api_key 
url = "https://api.thedogapi.com/v1/breeds?"
api_key = "&apikey=" + api_key

# %%
#create a request to view json data 
#test request to view layout
response = requests.get(url + api_key)

data = response.json()
pprint(data)
# Out:
# [{'bred_for': 'Small rodent hunting, lapdog',
#   'breed_group': 'Toy',
#   'height': {'imperial': '9 - 11.5', 'metric': '23 - 29'},
#   'id': 1,
#   'image': {'height': 1199,
#             'id': 'BJa4kxc4X',
#             'url': 'https://cdn2.thedogapi.com/images/BJa4kxc4X.jpg',
#             'width': 1600},
#   'life_span': '10 - 12 years',
#   'name': 'Affenpinscher',
#   'origin': 'Germany, France',
#   'reference_image_id': 'BJa4kxc4X',
#   'temperament': 'Stubborn, Curious, Playful, Adventurous, Active, Fun-loving',
#   'weight': {'imperial': '6 - 13', 'metric': '3 - 6'}},
#  {'bred_for': 'Coursing and hunting',
#   'breed_group': 'Hound',
#   'country_code': 'AG',
#   'height': {'imperial': '25 - 27', 'metric': '64 - 69'},
#   'id': 2,
#   'image': {'height': 380,
#             'id': 'hMyT4CDXR',
#             'url': 'https://cdn2.thedogapi.com/images/hMyT4CDXR.jpg',
#             'width': 606},
#   'life_span': '10 - 13 years',
#   'name': 'Afghan Hound',
# ...

# %%
#use pd.read_json to transform url json data into a df 
dog_api_df = pd.read_json(url)

# %%
#view dataframe
dog_api_df
# Out:
#                                             weight  \
# 0        {'imperial': '6 - 13', 'metric': '3 - 6'}
# 1     {'imperial': '50 - 60', 'metric': '23 - 27'}
# 2     {'imperial': '44 - 66', 'metric': '20 - 30'}
# 3     {'imperial': '40 - 65', 'metric': '18 - 29'}
# 4    {'imperial': '90 - 120', 'metric': '41 - 54'}
# ..                                             ...
# 167     {'imperial': '15 - 19', 'metric': '7 - 9'}
# 168   {'imperial': '45 - 70', 'metric': '20 - 32'}
# 169   {'imperial': '45 - 65', 'metric': '20 - 29'}
# 170     {'imperial': '9 - 31', 'metric': '4 - 14'}
# 171       {'imperial': '4 - 7', 'metric': '2 - 3'}
#
#                                              height   id  \
# 0     {'imperial': '9 - 11.5', 'metric': '23 - 29'}    1
# 1      {'imperial': '25 - 27', 'metric': '64 - 69'}    2
# 2                {'imperial': '30', 'metric': '76'}    3
# 3      {'imperial': '21 - 23', 'metric': '53 - 58'}    4
# 4      {'imperial': '28 - 34', 'metric': '71 - 86'}    5
# ...

# %%
#take out any unneccessary columns that will not support our visualizations 
dog_api_df.drop(columns=['origin',
                         'country_code','description','history',
                            'id','breed_group'])
# Out:
#                                             weight  \
# 0        {'imperial': '6 - 13', 'metric': '3 - 6'}
# 1     {'imperial': '50 - 60', 'metric': '23 - 27'}
# 2     {'imperial': '44 - 66', 'metric': '20 - 30'}
# 3     {'imperial': '40 - 65', 'metric': '18 - 29'}
# 4    {'imperial': '90 - 120', 'metric': '41 - 54'}
# ..                                             ...
# 167     {'imperial': '15 - 19', 'metric': '7 - 9'}
# 168   {'imperial': '45 - 70', 'metric': '20 - 32'}
# 169   {'imperial': '45 - 65', 'metric': '20 - 29'}
# 170     {'imperial': '9 - 31', 'metric': '4 - 14'}
# 171       {'imperial': '4 - 7', 'metric': '2 - 3'}
#
#                                              height  \
# 0     {'imperial': '9 - 11.5', 'metric': '23 - 29'}
# 1      {'imperial': '25 - 27', 'metric': '64 - 69'}
# 2                {'imperial': '30', 'metric': '76'}
# 3      {'imperial': '21 - 23', 'metric': '53 - 58'}
# 4      {'imperial': '28 - 34', 'metric': '71 - 86'}
# ...

# %%
#reorder df to put the breed name first 
dog_api_df = dog_api_df[["name", "bred_for","weight","height",'life_span','temperament','image','reference_image_id']]

# %%
pd.set_option('display.max_rows', None)

# %%
#rename 'name' column to match kaggle dataset to later merge
dog_api_df.rename(columns={'name': 'BreedName'}, inplace=True)
# Out:
# /Users/meredithgray/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
dog_api_df
# Out:
#                               BreedName  \
# 0                         Affenpinscher
# 1                          Afghan Hound
# 2                   African Hunting Dog
# 3                      Airedale Terrier
# 4                            Akbash Dog
# 5                                 Akita
# 6            Alapaha Blue Blood Bulldog
# 7                         Alaskan Husky
# 8                      Alaskan Malamute
# 9                      American Bulldog
# 10                       American Bully
# 11                  American Eskimo Dog
# 12      American Eskimo Dog (Miniature)
# 13                    American Foxhound
# 14            American Pit Bull Terrier
# 15       American Staffordshire Terrier
# 16               American Water Spaniel
# 17               Anatolian Shepherd Dog
# 18               Appenzeller Sennenhund
# 19                Australian Cattle Dog
# 20                    Australian Kelpie
# 21                  Australian Shepherd
# ...

# %% [markdown]
# # Kaggle Dataset (Dog Breed Characteristics)
# - Next we will import a csv from kaggle.com that lists canine breed characteristics such as popularity, temperment, average price, etc.
# - After cleaning the data and removing any unneccessary columns, we will merge it to the API dataframe on "BreedName"

# %%
# File to Load
file_to_load = "dog_breed_characteristics.csv"
# Read Purchasing File and store into Pandas data frame
dog_kaggle = pd.read_csv(file_to_load, encoding="utf-8")
dog_kaggle
# Out:
#                                          BreedName  \
# 0                                    Affenpinscher
# 1                                     Afghan Hound
# 2                                 Airedale Terrier
# 3                                           Akbash
# 4                                            Akita
# 5                                 Alaskan Malamute
# 6                                 American Bulldog
# 7                              American Eskimo Dog
# 8                        American Hairless Terrier
# 9                   American Staffordshire Terrier
# 10                          American Water Spaniel
# 11                              Anatolian Shepherd
# 12                          Appenzell Mountain Dog
# 13               Australian Cattle Dog/Blue Heeler
# 14                               Australian Kelpie
# 15                             Australian Shepherd
# 16                              Australian Terrier
# ...

# %%
#Drop unneeded columns 
new_kaggle= dog_kaggle.drop(columns=['AltBreedName', 'MaleWtKg','Intelligence','Group1',
                                     'Group2','Temperment','Watchdog','MalaysiaGuardedDog',
                                     'MalaysiaProhibitedDog','MalaysiaPopularity','PopularityUS2017'])

# %%
#Merge 2 dataframes 
merged_frames= dog_api_df.merge(new_kaggle, on='BreedName', how='left')

# %%
#view 
merged_frames
# Out:
#                               BreedName  \
# 0                         Affenpinscher
# 1                          Afghan Hound
# 2                   African Hunting Dog
# 3                      Airedale Terrier
# 4                            Akbash Dog
# 5                                 Akita
# 6            Alapaha Blue Blood Bulldog
# 7                         Alaskan Husky
# 8                      Alaskan Malamute
# 9                      American Bulldog
# 10                       American Bully
# 11                  American Eskimo Dog
# 12      American Eskimo Dog (Miniature)
# 13                    American Foxhound
# 14            American Pit Bull Terrier
# 15       American Staffordshire Terrier
# 16               American Water Spaniel
# 17               Anatolian Shepherd Dog
# 18               Appenzeller Sennenhund
# 19                Australian Cattle Dog
# 20                    Australian Kelpie
# 21                  Australian Shepherd
# ...

# %%
temperament= pd.DataFrame([merged_frames.BreedName, merged_frames.temperament]).transpose()

# %%
temperament
# Out:
#                               BreedName  \
# 0                         Affenpinscher
# 1                          Afghan Hound
# 2                   African Hunting Dog
# 3                      Airedale Terrier
# 4                            Akbash Dog
# 5                                 Akita
# 6            Alapaha Blue Blood Bulldog
# 7                         Alaskan Husky
# 8                      Alaskan Malamute
# 9                      American Bulldog
# 10                       American Bully
# 11                  American Eskimo Dog
# 12      American Eskimo Dog (Miniature)
# 13                    American Foxhound
# 14            American Pit Bull Terrier
# 15       American Staffordshire Terrier
# 16               American Water Spaniel
# 17               Anatolian Shepherd Dog
# 18               Appenzeller Sennenhund
# 19                Australian Cattle Dog
# 20                    Australian Kelpie
# 21                  Australian Shepherd
# ...

# %%
new = pd.DataFrame([merged_frames.BreedName, merged_frames.AvgPupPrice]).transpose()

# %%
new= new.dropna()

# %%
new.to_csv('Breed_and_Price.csv', index = False)

# %%
just_name= pd.DataFrame(new['BreedName'])
just_name
# Out:
#                           BreedName
# 0                     Affenpinscher
# 1                      Afghan Hound
# 3                  Airedale Terrier
# 5                             Akita
# 8                  Alaskan Malamute
# 9                  American Bulldog
# 11              American Eskimo Dog
# 15   American Staffordshire Terrier
# 16           American Water Spaniel
# 20                Australian Kelpie
# 21              Australian Shepherd
# 22               Australian Terrier
# 25                          Basenji
# 27                     Basset Hound
# 28                           Beagle
# 29                   Bearded Collie
# 30                        Beauceron
# 31               Bedlington Terrier
# 34             Bernese Mountain Dog
# 35                     Bichon Frise
# 36          Black and Tan Coonhound
# 37                       Bloodhound
# 38               Bluetick Coonhound
# 39                         Boerboel
# 40                    Border Collie
# ...

# %%
just_price= pd.DataFrame(new['AvgPupPrice'])
just_price
# Out:
#     AvgPupPrice
# 0        1000.0
# 1        2250.0
# 3         700.0
# 5        1000.0
# 8        1350.0
# 9         800.0
# 11        700.0
# 15        900.0
# 16        900.0
# 20        600.0
# 21        700.0
# 22       1250.0
# 25       1100.0
# 27        400.0
# 28        650.0
# 29       1300.0
# 30       1350.0
# 31       1900.0
# 34        900.0
# 35        850.0
# 36        350.0
# 37       1000.0
# 38        550.0
# 39       1750.0
# 40        700.0
# 41       1300.0
# 42        750.0
# 44        900.0
# 45        900.0
# 47       1100.0
# 49       1350.0
# 51       1350.0
# 52        850.0
# 55        400.0
# 57       1350.0
# 58        800.0
# 61        900.0
# 62        700.0
# 63       1000.0
# 64        700.0
# 66       2700.0
# 67        800.0
# 68        900.0
# 69      39000.0
# 70       1100.0
# 71        500.0
# 72        900.0
# 73        750.0
# 74       1400.0
# 77        900.0
# 78        700.0
# 79        600.0
# 80       3000.0
# 81       1500.0
# ...

# %%
merged_frames.to_csv('data/kaggle_api_merged.csv', index = False)

# %%
#viewing just BreedNames
breeds_only= pd.DataFrame(merged_frames['BreedName'])

# %%
pd.set_option('display.max_rows', 500)

# %%
breeds_only
# Out:
#                               BreedName
# 0                         Affenpinscher
# 1                          Afghan Hound
# 2                   African Hunting Dog
# 3                      Airedale Terrier
# 4                            Akbash Dog
# 5                                 Akita
# 6            Alapaha Blue Blood Bulldog
# 7                         Alaskan Husky
# 8                      Alaskan Malamute
# 9                      American Bulldog
# 10                       American Bully
# 11                  American Eskimo Dog
# 12      American Eskimo Dog (Miniature)
# 13                    American Foxhound
# 14            American Pit Bull Terrier
# 15       American Staffordshire Terrier
# 16               American Water Spaniel
# 17               Anatolian Shepherd Dog
# 18               Appenzeller Sennenhund
# 19                Australian Cattle Dog
# 20                    Australian Kelpie
# 21                  Australian Shepherd
# ...

# %% [markdown]
# # Web Scraping the AKC website
# - Next, we will scrape The American Kennel Club website to pull breeder info
# - This step will assist in our visualizations because it provides the breeder's zipcode

# %%
#create an executable path
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [/Users/meredithgray/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache

# %%
#visit akc website
url = "https://marketplace.akc.org/puppies"
browser.visit(url)

# %%
#create empty dictionary to store scraped data
breed_dict = []

#go through pages to get breed and breeder info 
for x in range(200): 
    html=browser.html
    soup = BeautifulSoup(html, 'html.parser')
    breeders = soup.find_all('div', class_ = 'breeder-litter-card__details')
    
    for breeder in breeders: 
        h4 = breeder.find('div')
        breed = h4.find('h4').text
        breed_loc = breeder.find('p', class_ = 'breeder-card__location').text
        print(breed)
        print(breed_loc)
    
        breed_dict.append({"breed": breed, "breeder location": breed_loc})
    #click the next button 
    try: 
        browser.links.find_by_partial_text('next').click()
    except: 
        print("got the breeders")
# Out:
# Rottweiler Puppies
# Thom WoodwardBattle Ground, WA 98604
# Poodle Puppies
# Marie HedemanPahrump, NV 89048
# Poodle Puppies
# Marie HedemanPahrump, NV 89048
# Ash's-Mystical Poodles
# Marie HedemanPahrump, NV 89048
# Champion bloodline Bulldog Puppies
# Isaac LaRongeSyosset, NY 11791
# River Ridge Rat Terriers
# Stacy McWilliams & Stacy ZimmermanTelford, PA 18969
# Tibetan Terrier Puppies
# Susan CarrTolland, CT 06084
# CHEROKEE BULLDOGS      ----Bulldog Puppies
# Cody SickleSyosset, NY 11791
# Stoneys
# Bonnie StoneyOlney Springs, CO 81062
# WINDROCK LLC
# Colin and Kimberly FritzlerTorrington, WY 82240
# Cutwater Portuguese Water Dogs
# Jane HardingChester, CT 06412
# Szumeria Kuvasz
# Constance Townsend-Brady or Lynn BradyFarmington, MN 55024
# JNEK Vizslas          AKC PLatinum Breeder…
# Kathy EngelsmanGlen Ellyn, IL 60137
# AviatorKennel.com Portuguese Water Dogs
# Michael and Cathy DuganShingle Springs, CA 95682
# Dyane Baldwin
# Dyane BaldwinNewport, PA 17074
# Lucy Heyman
# ...

# %%
breed_dict
# Out:
# [{'breed': 'Rottweiler Puppies',
#   'breeder location': 'Thom WoodwardBattle Ground, WA 98604'},
#  {'breed': 'Poodle Puppies',
#   'breeder location': 'Marie HedemanPahrump, NV 89048'},
#  {'breed': 'Poodle Puppies',
#   'breeder location': 'Marie HedemanPahrump, NV 89048'},
#  {'breed': "Ash's-Mystical Poodles",
#   'breeder location': 'Marie HedemanPahrump, NV 89048'},
#  {'breed': 'Champion bloodline Bulldog Puppies',
#   'breeder location': 'Isaac LaRongeSyosset, NY 11791'},
#  {'breed': 'River Ridge Rat Terriers',
#   'breeder location': 'Stacy McWilliams & Stacy ZimmermanTelford, PA 18969'},
#  {'breed': 'Tibetan Terrier Puppies',
#   'breeder location': 'Susan CarrTolland, CT 06084'},
#  {'breed': 'CHEROKEE BULLDOGS      ----Bulldog Puppies',
#   'breeder location': 'Cody SickleSyosset, NY 11791'},
#  {'breed': 'Stoneys',
#   'breeder location': 'Bonnie StoneyOlney Springs, CO 81062'},
#  {'breed': 'WINDROCK LLC',
# ...

# %%
#put scraped info into a datafraame 
breeder_df = pd.DataFrame.from_dict(breed_dict)
breeder_df
# Out:
#                                    breed  \
# 0                     Rottweiler Puppies
# 1                         Poodle Puppies
# 2                         Poodle Puppies
# 3                 Ash's-Mystical Poodles
# 4     Champion bloodline Bulldog Puppies
# ...                                  ...
# 3795                Kathy Bube, (Rexann)
# 3796             Merson Belgian Malinois
# 3797             Quiet Creek Bloodhounds
# 3798       Glen of Imaal Terrier Puppies
# 3799        Dykumos Rhodesian Ridgebacks
#
#                                        breeder location
# 0                  Thom WoodwardBattle Ground, WA 98604
# 1                        Marie HedemanPahrump, NV 89048
# 2                        Marie HedemanPahrump, NV 89048
# 3                        Marie HedemanPahrump, NV 89048
# 4                        Isaac LaRongeSyosset, NY 11791
# ...                                                 ...
# 3795                      Kathy BubeElizabeth, IN 47117
# ...

# %%
breeder_df[['BreedName','Type']] = breeder_df['breed'].str.split('Puppies', expand=True)
breeder_df
# Out:
#                                    breed  \
# 0                     Rottweiler Puppies
# 1                         Poodle Puppies
# 2                         Poodle Puppies
# 3                 Ash's-Mystical Poodles
# 4     Champion bloodline Bulldog Puppies
# ...                                  ...
# 3795                Kathy Bube, (Rexann)
# 3796             Merson Belgian Malinois
# 3797             Quiet Creek Bloodhounds
# 3798       Glen of Imaal Terrier Puppies
# 3799        Dykumos Rhodesian Ridgebacks
#
#                                        breeder location  \
# 0                  Thom WoodwardBattle Ground, WA 98604
# 1                        Marie HedemanPahrump, NV 89048
# 2                        Marie HedemanPahrump, NV 89048
# 3                        Marie HedemanPahrump, NV 89048
# 4                        Isaac LaRongeSyosset, NY 11791
# ...                                                 ...
# 3795                      Kathy BubeElizabeth, IN 47117
# ...

# %%
breeder_df= breeder_df.drop(columns=['breed','Type'])

# %%
breeder_df
# Out:
#                                        breeder location  \
# 0                  Thom WoodwardBattle Ground, WA 98604
# 1                        Marie HedemanPahrump, NV 89048
# 2                        Marie HedemanPahrump, NV 89048
# 3                        Marie HedemanPahrump, NV 89048
# 4                        Isaac LaRongeSyosset, NY 11791
# ...                                                 ...
# 3795                      Kathy BubeElizabeth, IN 47117
# 3796                      S  WilliamsonIrving, TX 75062
# 3797             Susan LaCroix HamilEncinitas, CA 92024
# 3798                      Ara LynnNew Ipswich, NH 03071
# 3799  Asta Palmer & Gabby McCormickValley Center, CA...
#
#                          BreedName
# 0                      Rottweiler
# 1                          Poodle
# 2                          Poodle
# 3           Ash's-Mystical Poodles
# 4      Champion bloodline Bulldog
# ...                            ...
# 3795          Kathy Bube, (Rexann)
# ...

# %%
#reorder to BreedName First 
new_breeder_df = breeder_df[["BreedName", "breeder location"]]

# %%
new_breeder_df
# Out:
#                          BreedName  \
# 0                      Rottweiler
# 1                          Poodle
# 2                          Poodle
# 3           Ash's-Mystical Poodles
# 4      Champion bloodline Bulldog
# ...                            ...
# 3795          Kathy Bube, (Rexann)
# 3796       Merson Belgian Malinois
# 3797       Quiet Creek Bloodhounds
# 3798        Glen of Imaal Terrier
# 3799  Dykumos Rhodesian Ridgebacks
#
#                                        breeder location
# 0                  Thom WoodwardBattle Ground, WA 98604
# 1                        Marie HedemanPahrump, NV 89048
# 2                        Marie HedemanPahrump, NV 89048
# 3                        Marie HedemanPahrump, NV 89048
# 4                        Isaac LaRongeSyosset, NY 11791
# ...                                                 ...
# 3795                      Kathy BubeElizabeth, IN 47117
# 3796                      S  WilliamsonIrving, TX 75062
# ...

# %%
#drop duplicate breeds 
breeder_drop_duplicates= new_breeder_df.drop_duplicates()

# %%
breeder_drop_duplicates
# Out:
#                                         BreedName  \
# 0                                     Rottweiler
# 1                                         Poodle
# 3                          Ash's-Mystical Poodles
# 4                     Champion bloodline Bulldog
# 5                        River Ridge Rat Terriers
# 6                                Tibetan Terrier
# 7             CHEROKEE BULLDOGS      ----Bulldog
# 8                                         Stoneys
# 9                                    WINDROCK LLC
# 10                 Cutwater Portuguese Water Dogs
# 11                                Szumeria Kuvasz
# 12    JNEK Vizslas          AKC PLatinum Breeder…
# 13        AviatorKennel.com Portuguese Water Dogs
# 14                                  Dyane Baldwin
# 15                                    Lucy Heyman
# 16                                        TRUMPET
# 17                   Miniature American Shepherd
# 18                  Miniature Longhair Dachshund
# ...

# %%
len(breeder_drop_duplicates)
# Out:
# 37

# %%
breeder_df.to_csv('breeder locations raw.csv', index = False)

# %%
browser.quit()

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
data = merged_frames.to_dict(orient='records')

try: 
    db = client['Final_Dog_db']
    collection = db['Final_Dog_collection']
    collection.insert_many(data)
    print('the eagle has landed')

except: 
    print('the eagle is still flying')
# Out:
# the eagle has landed
