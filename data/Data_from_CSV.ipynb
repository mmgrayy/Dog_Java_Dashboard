# %%
#import dependencies
import os
import csv
import pandas as pd

# %%
# File to Load
file_to_load = "Resources/dog_breed_characteristics.csv"
# Read Purchasing File and store into Pandas data frame
dog_characteristics = pd.read_csv(file_to_load, encoding="utf-8")
dog_characteristics
# Out:
#                            BreedName       AltBreedName        Group1  \
# 0                      Affenpinscher                NaN           Toy
# 1                       Afghan Hound                NaN      Sporting
# 2                   Airedale Terrier           Airedale       Terrier
# 3                             Akbash                NaN       Working
# 4                              Akita                NaN       Working
# ..                               ...                ...           ...
# 240     Wire-haired Pointing Griffon                NaN      Sporting
# 241               Wirehaired Terrier                NaN       Terrier
# 242  Xoloitzcuintle/Mexican Hairless   Mexican Hairless  Non Sporting
# 243        Yellow Labrador Retriever                NaN      Sporting
# 244         Yorkshire Terrier Yorkie  Yorkshire Terrier           Toy
#
#         Group2  MaleWtKg                                         Temperment  \
# ...

# %%
 # Remove unecessary columns from the DataFrame and save the new DataFrame
    # Only keep: "BreedName", "Group1", "Temperment", "AvgPupPrice", "PopularityUS2017"

dogs_cleaned_df = dog_characteristics[["BreedName", "Group1", "Temperment", "AvgPupPrice",
                       "PopularityUS2017"]]

dogs_cleaned_df.head()
# Out:
#           BreedName    Group1  \
# 0     Affenpinscher       Toy
# 1      Afghan Hound  Sporting
# 2  Airedale Terrier   Terrier
# 3            Akbash   Working
# 4             Akita   Working
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...         1000
# 1     Aloof, Clownish, Dignified, Happy, Independent         2250
# 2  Alert, Confident, Courageous, Friendly, Intell...          700
# 3  Affectionate, Alert, Courageous, Independent, ...          600
# 4  Alert, Courageous, Dignified, Docile, Friendly...         1000
#
#    PopularityUS2017
# 0             147.0
# 1              93.0
# 2              55.0
# 3               NaN
# 4              47.0

# %%
# Push the remade DataFrame to a new CSV file
dogs_cleaned_df.to_csv("Output/dog_breed_characteristics_clean.csv",
                  encoding="utf-8", index=False, header=True)
